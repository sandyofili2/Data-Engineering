# %% [markdown]
# <h1 style="text-align:center">Austin Crime Statistics From 2015 until 2016 </h1>

# %% [markdown]
# <p> This dataset monitors Part 1 crimes which are murder, rape, robbery, aggravated assault, burglary, larceny, motor vehicle theft, human trafficking and arson in Austin Texas. It monitors the increase and decrease of Part 1 crimes from January 1st 2015 until December 31st 2016. We can compare the information in the dataset to policies that were implemented in Austin and how those policies impacted the community when it comes to Part 1 crimes. The information will then be used to make suggestions on how to decrease certain Part 1 crimes.
# </p>

# %%
import pandas as pd
import numpy as np

# %%
                                    #Uploading of dataset

# %%
with open('Annual_Crime_Dataset_2015.csv') as d:
    Austin_2015 = pd.read_csv(d)

# %%
Austin_2015
# Out:
#        GO Primary Key  Council District         GO Highest Offense Desc  \
# 0           201510782               4.0  AGG ROBBERY/DEADLY WEAPON
# 1           201511231               4.0  ROBBERY BY ASSAULT
# 2           201511736               1.0  BURGLARY OF RESIDENCE
# 3           201511433               4.0  BURGLARY OF RESIDENCE
# 4           201511936               2.0  BURGLARY OF RESIDENCE
# ...               ...               ...                             ...
# 38568     20153650803               1.0  THEFT
# 38569     20155056956               6.0  THEFT
# 38570     20153651059              10.0  THEFT
# 38571     20153651185               1.0  THEFT
# 38572     20155056975               7.0  THEFT
#
#       Highest NIBRS/UCR Offense Description GO Report Date  \
# 0                                   Robbery       1-Jan-15
# 1                                   Robbery       1-Jan-15
# 2                                  Burglary       1-Jan-15
# ...

# %%
with open('2016_Annual_Crime_Data_20240414.csv') as c:
    Austin_2016 = pd.read_csv(c)

# %%
Austin_2016
# Out:
#        GO Primary Key  Council District         GO Highest Offense Desc  \
# 0        2.016102e+08               8.0  AGG ASLT ENHANC STRANGL/SUFFOC
# 1        2.016106e+08               9.0  THEFT
# 2        2.016109e+08               4.0  AGG ROBBERY/DEADLY WEAPON
# 3        2.016109e+08               9.0  THEFT
# 4        2.016110e+08               4.0  SEXUAL ASSAULT W/ OBJECT
# ...               ...               ...                             ...
# 37456    2.016505e+10               7.0  THEFT
# 37457    2.016505e+10               9.0  THEFT
# 37458    2.016801e+10               1.0  BURGLARY OF VEHICLE
# 37459    2.016801e+10               3.0  BURGLARY OF VEHICLE
# 37460    2.016801e+10               9.0  BURGLARY OF VEHICLE
#
#       Highest NIBRS/UCR Offense Description GO Report Date  \
# 0                               Agg Assault       1-Jan-16
# 1                                     Theft       1-Jan-16
# 2                                   Robbery       1-Jan-16
# ...

# %%
                                            #Clean Dataset

# %%
Austin_2015.isna().sum()
Austin_2016.isna().sum() #Checking for rows with null or nan values
# Out:
# GO Primary Key                              1
# Council District                          256
# GO Highest Offense Desc                     0
# Highest NIBRS/UCR Offense Description       0
# GO Report Date                              0
# GO Location                               759
# Clearance Status                         1719
# Clearance Date                           1719
# GO District                                 0
# GO Location Zip                           167
# GO Census Tract                           167
# GO X Coordinate                           867
# GO Y Coordinate                           867
# dtype: int64

# %%
Austin2015 = Austin_2015.copy() #making copy of df incase of mistake will be able to go back to initial dataframe

# %%
Austin2015 = Austin2015.dropna()

# %%
Austin2015.isna().sum()
# Out:
# GO Primary Key                           0
# Council District                         0
# GO Highest Offense Desc                  0
# Highest NIBRS/UCR Offense Description    0
# GO Report Date                           0
# GO Location                              0
# Clearance Status                         0
# Clearance Date                           0
# GO District                              0
# GO Location Zip                          0
# GO Census Tract                          0
# GO X Coordinate                          0
# GO Y Coordinate                          0
# dtype: int64

# %%
Austin2016 = Austin_2016.copy()

# %%
Austin2016= Austin2016.dropna()

# %%
Austin2016.describe()
Austin2015.describe()
# Out:
#        GO Primary Key  Council District  GO Location Zip  GO Census Tract  \
# count    3.609000e+04      36090.000000     36090.000000     36090.000000
# mean     1.777909e+10          5.233555     78732.811444        71.807817
# std      6.156109e+09          2.814798        25.790616       683.868791
# min      2.015103e+08          1.000000     78613.000000         1.010000
# 25%      2.015189e+10          3.000000     78719.000000        15.030000
# 50%      2.015500e+10          5.000000     78744.000000        18.220000
# 75%      2.015503e+10          8.000000     78752.000000        23.040000
# max      2.015800e+10         10.000000     78759.000000      9800.000000
#
#        GO X Coordinate  GO Y Coordinate
# count     3.609000e+04     3.609000e+04
# mean      3.115695e+06     1.008007e+07
# std       1.500793e+04     2.843616e+04
# min       3.056450e+06     1.001173e+07
# 25%       3.107289e+06     1.005780e+07
# 50%       3.116494e+06     1.007676e+07
# ...

# %%
Austin2015
# Out:
#        GO Primary Key  Council District         GO Highest Offense Desc  \
# 0           201510782               4.0  AGG ROBBERY/DEADLY WEAPON
# 1           201511231               4.0  ROBBERY BY ASSAULT
# 2           201511736               1.0  BURGLARY OF RESIDENCE
# 3           201511433               4.0  BURGLARY OF RESIDENCE
# 4           201511936               2.0  BURGLARY OF RESIDENCE
# ...               ...               ...                             ...
# 38567     20153650715               9.0  THEFT
# 38569     20155056956               6.0  THEFT
# 38570     20153651059              10.0  THEFT
# 38571     20153651185               1.0  THEFT
# 38572     20155056975               7.0  THEFT
#
#       Highest NIBRS/UCR Offense Description GO Report Date  \
# 0                                   Robbery       1-Jan-15
# 1                                   Robbery       1-Jan-15
# 2                                  Burglary       1-Jan-15
# ...

# %%
Austin2015 = Austin2015.rename(columns={'Council District': 'Council_District',
                                        'GO Location Zip': 'GO_Location_Zip',
                                        'GO Census Tract': 'GO_Census_Tract',
                                        'GO X Coordinate': 'GO_X_Coordinate',
                                        'GO Y Coordinate ': 'GO_Y_Coordinate '
                                        
                                       })

# %%
Austin2016 = Austin2016.rename(columns={'GO Primary Key':'GO_Primary_Key',
                                        'Council District': 'Council_District',
                                        'GO Location Zip': 'GO_Location_Zip',
                                        'GO Census Tract': 'GO_Census_Tract',
                                        'GO X Coordinate': 'GO_X_Coordinate',
                                        'GO Y Coordinate ': 'GO_Y_Coordinate '
                                        
                                       })

# %%
Austin2015.dtypes #Checking datatypes and converting where neccessary
# Out:
# GO Primary Key                             int64
# Council_District                         float64
# GO Highest Offense Desc                   object
# Highest NIBRS/UCR Offense Description     object
# GO Report Date                            object
# GO Location                               object
# Clearance Status                          object
# Clearance Date                            object
# GO District                               object
# GO_Location_Zip                          float64
# GO_Census_Tract                          float64
# GO_X_Coordinate                          float64
# GO Y Coordinate                          float64
# dtype: object

# %%
Austin2015['Council_District'] = Austin2015['Council_District'].astype(int)
Austin2015['GO_Location_Zip'] = Austin2015['GO_Location_Zip'].astype(int)
Austin2015['GO_Census_Tract'] = Austin2015['GO_Census_Tract'].astype(int)
Austin2015['GO_X_Coordinate'] = Austin2015['GO_X_Coordinate'].astype(int)
Austin2015['GO Y Coordinate'] = Austin2015['GO Y Coordinate'].astype(int)

# %%
Austin2016.dtypes
# Out:
# GO_Primary_Key                           float64
# Council_District                         float64
# GO Highest Offense Desc                   object
# Highest NIBRS/UCR Offense Description     object
# GO Report Date                            object
# GO Location                               object
# Clearance Status                          object
# Clearance Date                            object
# GO District                               object
# GO_Location_Zip                          float64
# GO_Census_Tract                          float64
# GO_X_Coordinate                          float64
# GO Y Coordinate                          float64
# dtype: object

# %%
Austin2016['GO_Primary_Key'] = Austin2016['GO_Primary_Key'].astype(int)
Austin2016['Council_District'] = Austin2016['Council_District'].astype(int)
Austin2016['GO_Location_Zip'] = Austin2016['GO_Location_Zip'].astype(int)
Austin2016['GO_Census_Tract'] = Austin2016['GO_Census_Tract'].astype(int)
Austin2016['GO_X_Coordinate'] = Austin2016['GO_X_Coordinate'].astype(int)
Austin2016['GO Y Coordinate'] = Austin2016['GO Y Coordinate'].astype(int)

# %%
Austin2015.info()
Austin2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36090 entries, 0 to 38572
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   GO Primary Key                         36090 non-null  int64
#  1   Council_District                       36090 non-null  int64
#  2   GO Highest Offense Desc                36090 non-null  object
#  3   Highest NIBRS/UCR Offense Description  36090 non-null  object
#  4   GO Report Date                         36090 non-null  object
#  5   GO Location                            36090 non-null  object
#  6   Clearance Status                       36090 non-null  object
#  7   Clearance Date                         36090 non-null  object
#  8   GO District                            36090 non-null  object
#  9   GO_Location_Zip                        36090 non-null  int64
# ...

# %%
                        #Load data to Google Cloud Storage

# %%
pip install gcsfs
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
Austin2015.to_csv('gs://austincrimedata/Austin2015.csv')

# %%
Austin2016.to_csv('gs://austincrimedata/Austin2016.csv')
